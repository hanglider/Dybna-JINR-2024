# %%
import numpy as np
import pandas as pd
import csv
from pathlib import Path
import json
import os
main_dir = Path(r'data/csv_data')

# %%
# словарь с ключевыми словами по ядерной физике
high_energy_physics_terms = set([
    "quark", "quarks", "lepton", "leptons", "boson", "bosons", "Higgs", "Higgses", 
    "neutrino", "neutrinos", "photon", "photons", "gluon", "gluons", "proton", "protons", 
    "neutron", "neutrons", "electron", "electrons", "positron", "positrons", "antimatter", 
    "antimatters", "particle", "particles", "accelerator", "accelerators", "collider", 
    "colliders", "synchrotron", "synchrotrons", "hadron", "hadrons", "meson", "mesons", 
    "fermion", "fermions", "muon", "muons", "tau", "taus", "graviton", "gravitons", 
    "supersymmetry", "supersymmetries", "quantum", "quantums", "chromodynamics", 
    "strong_force", "strong_forces", "weak_force", "weak_forces", "electromagnetic_force", 
    "electromagnetic_forces", "standard_model", "standard_models", "quantum_field_theory", 
    "quantum_field_theories", "spontaneous_symmetry_breaking", "grand_unification", 
    "grand_unifications", "dark_matter", "dark_matters", "dark_energy", "dark_energies", 
    "cosmic_ray", "cosmic_rays", "black_hole", "black_holes", "string_theory", 
    "string_theories", "extra_dimension", "extra_dimensions", "tachyon", "tachyons", 
    "renormalization", "renormalizations", "loop_quantum_gravity", "loop_quantum_gravities", 
    "fermion", "fermions", "neutrino_oscillation", "neutrino_oscillations", "mass", "masses", 
    "energy", "energies", "feynman_diagram", "feynman_diagrams", "beta_decay", "beta_decays", 
    "big_bang", "big_bangs", "cosmology", "cosmologies", "superstring_theory", 
    "superstring_theories",
    "Black Hole physics",
    "Curved spacetime",
    "Experimental realizations",
    "Hawking radiation",
    "Massless scalar fields",
    "Quantum field theory",
    "Quantum many-body systems",
    "Static spacetime",
    "Quantum theory",
    "Bosonic fields",
    "Nonclassical effects",
    "Atom-field interaction",
    "Cavity Quantum Electrodynamics",
    "Wigner-Yanase skew information",
    "Jaynes-Cummings model",
    "Energy gap",
    "III-V semiconductors",
    "High electron mobility",
    "Magneto-transport characteristics",
    "Quantum optics",
    "Wave packets",
    "Quantum state transfers",
    "Topological charges",
    "Phase gradient",
    "Transverse planes",
    "X-Y model",
    
])

# %%
def find_articles(keywords: set, df: pd.DataFrame) -> pd.DataFrame:
    """
    Find articles in the DataFrame where at least 2 of the keywords are present in the "Ключевые слова указателя" column.

    Args:
    keywords (set): A set of keywords to search for.
    df (pd.DataFrame): The DataFrame to search in.

    Returns:
    pd.DataFrame: A new DataFrame containing only the rows where at least 2 of the keywords are present in the "Ключевые слова указателя" column.
    """
    # Convert the set of keywords to a list of lowercase strings
    keywords = [kw.lower() for kw in keywords]

    # Filter out rows with NaN values in the "Ключевые слова указателя" column and create a copy
    if 'Index Keywords' in df.columns:
        df.rename(columns={'Index Keywords': 'Ключевые слова указателя'}, inplace=True)
    
    try:
        df_filtered = df.dropna(subset=['Ключевые слова указателя']).copy()
    except:
        print('NO SUCH COLUMN Ключевые слова указателя')
    
    # Using .loc to safely modify the DataFrame
    df_filtered.loc[:, 'match_count'] = df_filtered['Ключевые слова указателя'].str.lower().str.findall('|'.join(keywords)).str.len()

    # Find rows where at least 2 keywords are present in the "Ключевые слова указателя" column
    mask = df_filtered['match_count'] >= 2

    # Return a new DataFrame containing only the matching rows
    return df_filtered[mask]

# %%
# Function to process each file
def process_file(file_path, organisations_dict):

    # Read CSV file
    # WARNING :  ТУТ ВЫЛЕЗАЕТ ОШИБКА
    # TODO
    df_current = pd.read_csv(file_path, low_memory=False)
    
    #df_current = df_current.drop(['Том', 'Выпуск','Страница начала','Страница окончания','Количество страниц','Статья №','Год','Идентификатор PubMed','Сокращенное название источника','Тип документа','СТАДИЯ ПУБЛИКАЦИИ','Open Access (открытый доступ)','CODEN','ISBN','Место проведения конференции','Дата конференции','Название конференции','Код конференции','Редакторы','Спонсоры','Адрес для корреспонденции','Текст о финансировании','Сведения о финансировании','Ссылка','Номера молекулярных последовательностей','Химические вещества/CAS','Фирменные наименования','Производители','DOI','ISSN','Язык оригинального документа','Источник','EID','Идентификатор автора(ов)'], axis=1)
    df_current = find_articles(keywords=high_energy_physics_terms,df=df_current)

            # Filter out rows with NaN values in the "Ключевые слова указателя" column and create a copy
    if 'Affiliations' in df_current.columns:
        df_current.rename(columns={'Affiliations': 'Организации'}, inplace=True)
        
    if 'Организации' in df_current.columns:
            # Split the organisations column by semicolon and explode it
            df_current = df_current.assign(Organisation=df_current['Организации'].str.split(';')).explode('Организации')
            # Strip whitespace from organisation names

            
            #Update count in organisations_dict
            for org_list in df_current['Organisation']:
                if isinstance(org_list, list):
                    for org in org_list:
                        if(org in organisations_dict):
                            organisations_dict[org.strip()] += 1
                        else:
                            organisations_dict[org.strip()] = 1
    
    return organisations_dict

# %%
def top_5_pairs(dictionary):
    # Сортируем словарь по значениям в порядке убывания и берём первые 5 пар
    top_pairs = sorted(dictionary.items(), key=lambda item: item[1], reverse=True)[:5]
    
    return dict(top_pairs)

# %%
# Функция для рекурсивного поиска и обработки всех CSV файлов в директориях
# ПРОСТО НАПИСАНА ГПТ, МЫ ЕЩЕ НЕ УСПЕЛИ ЕЕ ИСПОЛЬЗОВАТЬ
def process_directory(directory_path):
    organisations_dict = dict()

    # Рекурсивно обходим папки
    for root, dirs, files in os.walk(directory_path):
        for file in files:
            if file.endswith(".csv"):
                file_path = os.path.join(root, file)
                print(f"Обработка файла: {file_path}")
                organisations_dict = process_file(file_path, organisations_dict)


    # После обработки всех файлов, группируем результаты по организациям
    final_stats = top_5_pairs(organisations_dict)
    
    return final_stats

# %%
directory_path = 'data/'

# Обработка всех файлов
top_organisations = process_directory(directory_path)
# Out:
# Обработка файла: data/2022/china_2022_mar_(9, 16).csv
# Обработка файла: data/2022/china_2022_nov_(17, 24).csv
# Обработка файла: data/2022/china_2022_jun_(9, 16).csv
# Обработка файла: data/2022/china_2022_nov_(9, 16).csv
# Обработка файла: data/2022/china_2022_feb_(9, 16).csv
# Обработка файла: data/2022/china_2022_apr_(9, 16).csv
# Обработка файла: data/2022/china_2022_jun_(1, 8).csv
# Обработка файла: data/2022/china_2022_sep_(24, 31).csv
# Обработка файла: data/2022/china_2022_may_(24, 31).csv
# Обработка файла: data/2022/china_2022_jul_(17, 24).csv
# Обработка файла: data/2022/china_2022_feb_(17, 24).csv
# Обработка файла: data/2022/china_2022_nov_(1, 8).csv
# Обработка файла: data/2022/china_2022_aug_(17, 24).csv
# Обработка файла: data/2022/china_2022_jan_(17, 24).csv
# Обработка файла: data/2022/china_2022_apr_(24, 31).csv
# Обработка файла: data/2022/china_2022_may_(1, 8).csv
# Обработка файла: data/2022/china_2022_jun_(24, 31).csv
# Обработка файла: data/2022/china_2022_jan_(9, 16).csv
# Обработка файла: data/2022/china_2022_jul_(1, 8).csv
# Обработка файла: data/2022/china_2022_dec_(9, 16).csv
# Обработка файла: data/2022/china_2022_dec_(17, 24).csv
# Обработка файла: data/2022/china_2022_oct_(17, 24).csv
# Обработка файла: data/2022/china_2022_oct_(9, 16).csv
# Обработка файла: data/2022/china_2022_oct_(1, 8).csv
# Обработка файла: data/2022/china_2022_sep_(1, 8).csv
# Обработка файла: data/2022/china_2022_mar_(24, 31).csv
# Обработка файла: data/2022/china_2022_sep_(9, 16).csv
# Обработка файла: data/2022/china_2022_mar_(1, 8).csv
# Обработка файла: data/2022/china_2022_nov_(24, 31).csv
# Обработка файла: data/2022/china_2022_aug_(9, 16).csv
# Обработка файла: data/2022/china_2022_sep_(17, 24).csv
# Обработка файла: data/2022/china_2022_feb_(1, 8).csv
# Обработка файла: data/2022/china_2022_jul_(24, 31).csv
# Обработка файла: data/2022/china_2022_may_(17, 24).csv
# Обработка файла: data/2022/china_2022_jan_(24, 31).csv
# Обработка файла: data/2022/china_2022_apr_(17, 24).csv
# Обработка файла: data/2022/china_2022_aug_(24, 31).csv
# Обработка файла: data/2022/china_2022_feb_(24, 31).csv
# Обработка файла: data/2022/china_2022_aug_(1, 8).csv
# Обработка файла: data/2022/china_2022_jan_(1, 8).csv
# Обработка файла: data/2022/china_2022_jul_(9, 16).csv
# Обработка файла: data/2022/china_2022_jun_(17, 24).csv
# Обработка файла: data/2022/china_2022_may_(9, 16).csv
# Обработка файла: data/2022/china_2022_dec_(1, 8).csv
# Обработка файла: data/2022/china_2022_dec_(24, 31).csv
# Обработка файла: data/2022/china_2022_mar_(17, 24).csv
# Обработка файла: data/2022/china_2022_oct_(24, 31).csv
# Обработка файла: data/2024/china_2024_may_(17, 24).csv
# Обработка файла: data/2024/china_2024_jul_(24, 31).csv
# Обработка файла: data/2024/china_2024_aug_(24, 31).csv
# Обработка файла: data/2024/china_2024_apr_(17, 24).csv
# Обработка файла: data/2024/china_2024_apr_(1, 8).csv
# Обработка файла: data/2024/china_2024_nov_(1, 8).csv
# Обработка файла: data/2024/china_2024_feb_(24, 31).csv
# Обработка файла: data/2024/china_2024_oct_(9, 16).csv
# Обработка файла: data/2024/china_2024_nov_(24, 31).csv
# Обработка файла: data/2024/china_2024_sep_(17, 24).csv
# Обработка файла: data/2024/china_2024_dec_(9, 16).csv
# Обработка файла: data/2024/china_2024_jun_(1, 8).csv
# Обработка файла: data/2024/china_2024_dec_(24, 31).csv
# Обработка файла: data/2024/china_2024_feb_(9, 16).csv
# Обработка файла: data/2024/china_2024_nov_(9, 16).csv
# Обработка файла: data/2024/china_2024_jun_(9, 16).csv
# Обработка файла: data/2024/china_2024_apr_(9, 16).csv
# Обработка файла: data/2024/china_2024_oct_(1, 8).csv
# Обработка файла: data/2024/china_2024_sep_(1, 8).csv
# Обработка файла: data/2024/china_2024_oct_(24, 31).csv
# Обработка файла: data/2024/china_2024_jun_(17, 24).csv
# Обработка файла: data/2024/china_2024_may_(1, 8).csv
# Обработка файла: data/2024/china_2024_jul_(1, 8).csv
# Обработка файла: data/2024/china_2024_feb_(1, 8).csv
# Обработка файла: data/2024/china_2024_jul_(17, 24).csv
# Обработка файла: data/2024/china_2024_may_(9, 16).csv
# Обработка файла: data/2024/china_2024_may_(24, 31).csv
# Обработка файла: data/2024/china_2024_feb_(17, 24).csv
# Обработка файла: data/2024/china_2024_jul_(9, 16).csv
# Обработка файла: data/2024/china_2024_apr_(24, 31).csv
# Обработка файла: data/2024/china_2024_aug_(17, 24).csv
# Обработка файла: data/2024/china_2024_nov_(17, 24).csv
# Обработка файла: data/2024/china_2024_sep_(24, 31).csv
# Обработка файла: data/2024/china_2024_dec_(17, 24).csv
# Обработка файла: data/2024/china_2024_dec_(1, 8).csv
# Обработка файла: data/2024/china_2024_oct_(17, 24).csv
# Обработка файла: data/2024/china_2024_aug_(9, 16).csv
# Обработка файла: data/2024/china_2024_sep_(9, 16).csv
# Обработка файла: data/2024/china_2024_jun_(24, 31).csv
# Обработка файла: data/2024/china_2024_aug_(1, 8).csv
# Обработка файла: data/2023/china_2023_apr_(1, 8).csv
# Обработка файла: data/2023/china_2023_dec_(9, 16).csv
# Обработка файла: data/2023/china_2023_jun_(24, 31).csv
# Обработка файла: data/2023/china_2023_nov_(1, 8).csv
# Обработка файла: data/2023/china_2023_oct_(9, 16).csv
# Обработка файла: data/2023/china_2023_dec_(17, 24).csv
# Обработка файла: data/2023/china_2023_jun_(1, 8).csv
# Обработка файла: data/2023/china_2023_mar_(24, 31).csv
# Обработка файла: data/2023/china_2023_oct_(17, 24).csv
# Обработка файла: data/2023/china_2023_sep_(1, 8).csv
# Обработка файла: data/2023/china_2023_oct_(1, 8).csv
# Обработка файла: data/2023/china_2023_nov_(17, 24).csv
# Обработка файла: data/2023/china_2023_sep_(24, 31).csv
# Обработка файла: data/2023/china_2023_jul_(1, 8).csv
# Обработка файла: data/2023/china_2023_jul_(17, 24).csv
# Обработка файла: data/2023/china_2023_mar_(9, 16).csv
# Обработка файла: data/2023/china_2023_may_(24, 31).csv
# Обработка файла: data/2023/china_2023_apr_(9, 16).csv
# Обработка файла: data/2023/china_2023_jun_(9, 16).csv
# Обработка файла: data/2023/china_2023_nov_(9, 16).csv
# Обработка файла: data/2023/china_2023_feb_(9, 16).csv
# Обработка файла: data/2023/china_2023_apr_(24, 31).csv
# Обработка файла: data/2023/china_2023_aug_(17, 24).csv
# Обработка файла: data/2023/china_2023_feb_(17, 24).csv
# Обработка файла: data/2023/china_2023_may_(1, 8).csv
# Обработка файла: data/2023/china_2023_jun_(17, 24).csv
# Обработка файла: data/2023/china_2023_feb_(1, 8).csv
# Обработка файла: data/2023/china_2023_jul_(9, 16).csv
# Обработка файла: data/2023/china_2023_dec_(24, 31).csv
# Обработка файла: data/2023/china_2023_may_(9, 16).csv
# Обработка файла: data/2023/china_2023_mar_(1, 8).csv
# Обработка файла: data/2023/china_2023_oct_(24, 31).csv
# Обработка файла: data/2023/china_2023_mar_(17, 24).csv
# Обработка файла: data/2023/china_2023_nov_(24, 31).csv
# Обработка файла: data/2023/china_2023_sep_(17, 24).csv
# Обработка файла: data/2023/china_2023_dec_(1, 8).csv
# Обработка файла: data/2023/china_2023_sep_(9, 16).csv
# Обработка файла: data/2023/china_2023_aug_(9, 16).csv
# Обработка файла: data/2023/china_2023_may_(17, 24).csv
# Обработка файла: data/2023/china_2023_jul_(24, 31).csv
# Обработка файла: data/2023/china_2023_feb_(24, 31).csv
# Обработка файла: data/2023/china december 2023.csv
# Обработка файла: data/2023/china_2023_aug_(1, 8).csv
# Обработка файла: data/2023/china_2023_aug_(24, 31).csv
# Обработка файла: data/2023/china_2023_apr_(17, 24).csv
# Обработка файла: data/2021/ch 21 22.csv
# Обработка файла: data/2021/ch 21 23.csv
# Обработка файла: data/2021/ch 21 2.csv
# Обработка файла: data/2021/ch feb med chem 21.csv
# Обработка файла: data/2021/ch 21 21.csv
# Обработка файла: data/2021/ch 21 20.csv
# Обработка файла: data/2021/ch 21 3.csv
# Обработка файла: data/2021/ch 21 7.csv
# Обработка файла: data/2021/ch 21 24.csv
# Обработка файла: data/2021/ch 21 18.csv
# Обработка файла: data/2021/ch 21 19.csv
# Обработка файла: data/2021/ch 21 25.csv
# Обработка файла: data/2021/ch 21 6.csv
# Обработка файла: data/2021/ch jan last 21.csv
# Обработка файла: data/2021/ch 21 4.csv
# Обработка файла: data/2021/ch 21.csv
# Обработка файла: data/2021/china_2021_dec_(24, 31).csv
# Обработка файла: data/2021/ch 21 26.csv
# Обработка файла: data/2021/ch 21 5.csv
# Обработка файла: data/2021/china_2021_dec_(1, 8).csv
# Обработка файла: data/2021/ch jan 1-8 21.csv
# Обработка файла: data/2021/china_2021_dec_(17, 24).csv
# Обработка файла: data/2021/china_2021_dec_(9, 16).csv
# Обработка файла: data/2021/ch 21 8.csv
# Обработка файла: data/2021/ch 21 17.csv
# Обработка файла: data/2021/ch 21 16.csv
# Обработка файла: data/2021/ch feb engi 21.csv
# Обработка файла: data/2021/ch 21 9.csv
# Обработка файла: data/2021/ch 21 14.csv
# Обработка файла: data/2021/ch 21 15.csv
# Обработка файла: data/2021/ch 21 11.csv
# Обработка файла: data/2021/ср 21 27.csv
# Обработка файла: data/2021/ch 21 10.csv
# Обработка файла: data/2021/ch 21 12.csv
# Обработка файла: data/2021/ch jan 21.csv
# Обработка файла: data/2021/ch 21 13.csv
# Обработка файла: data/2020/meds comp.csv
# Обработка файла: data/2020/feb 2.csv
# Обработка файла: data/2020/feb 3.csv
# Обработка файла: data/2020/engineering.csv
# Обработка файла: data/2020/dec 4.csv
# Обработка файла: data/2020/may 3.csv
# Обработка файла: data/2020/feb 1.csv
# Обработка файла: data/2020/sep med - eng.csv
# Обработка файла: data/2020/chem med oct.csv
# Обработка файла: data/2020/may - engi - chem.csv
# Обработка файла: data/2020/june - med phys mat.csv
# Обработка файла: data/2020/dec 3.csv
# Обработка файла: data/2020/march.csv
# Обработка файла: data/2020/april 1.csv
# Обработка файла: data/2020/oct eng.csv
# Обработка файла: data/2020/april 3.csv
# Обработка файла: data/2020/aug comp eng.csv
# Обработка файла: data/2020/april 2.csv
# Обработка файла: data/2020/jan 4.csv
# Обработка файла: data/2020/may - med -bio - env.csv
# Обработка файла: data/2020/jan 3.csv
# Обработка файла: data/2020/april 4.csv
# Обработка файла: data/2020/june 3.csv
# Обработка файла: data/2020/env.csv
# Обработка файла: data/2020/march 2.csv
# Обработка файла: data/2020/june 1.csv
# Обработка файла: data/2020/march 3.csv
# Обработка файла: data/2020/aug 3.csv
# Обработка файла: data/2020/sep 3.csv
# Обработка файла: data/2020/dec eng - env.csv
# Обработка файла: data/2020/june 4.csv
# Обработка файла: data/2020/sep 4.csv
# Обработка файла: data/2020/oct 4.csv
# Обработка файла: data/2020/materials - medicine.csv
# Обработка файла: data/2020/nov 3.csv
# Обработка файла: data/2020/nov 2.csv
# Обработка файла: data/2020/oct 5.csv
# Обработка файла: data/2020/dec mat - phys.csv
# Обработка файла: data/2020/sep mat - phys.csv
# Обработка файла: data/2020/nov 5.csv
# Обработка файла: data/2020/nov 4.csv
# Обработка файла: data/2020/eng mat.csv
# Обработка файла: data/2020/oct 3.csv
# Обработка файла: data/2020/aug phys med.csv

# %%
top_organisations
# Out:
# {'Guangxi Key Laboratory of Low Carbon Energy Materials, School of Chemistry and Pharmaceutical Sciences, Guangxi Normal University, Guilin, 541004, China': 33,
#  'Key Laboratory of Luminescence Analysis and Molecular Sensing (Southwest University), Ministry of Education, College of Chemistry and Chemical Engineering, Southwest University, Chongqing, 400715, China': 31,
#  'Key Laboratory of Luminescence Analysis and Molecular Sensing (Southwest University), Ministry of Education, School of Chemistry and Chemical Engineering, Southwest University, Chongqing, 400715, China': 29,
#  'School of Chemistry and Chemical Engineering, Ningxia Key Laboratory of Solar Chemical Conversion Technology, Key Laboratory for Chemical Engineering and Technology, State Ethnic Affairs Commission, North Minzu University, Yinchuan, 750021, China': 28,
#  "School of Mechatronic Engineering, Xi'an Technological University, Xi'an, 710021, China": 27}
